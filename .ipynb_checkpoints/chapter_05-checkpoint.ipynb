# %%
import os
from pyspark.sql import SparkSession
import pyspark.sql.functions as F

spark = SparkSession.builder.getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 26/03/22 12:01:10 WARN Utils: Your hostname, humacao, resolves to a loopback address: 127.0.1.1; using 192.168.68.83 instead (on interface wlp2s0)
# 26/03/22 12:01:10 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/03/22 12:01:11 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
DIRECTORY = "./data/broadcast_logs"

# %%
logs = (
    spark.read.csv(
        os.path.join(DIRECTORY, "BroadcastLogs_2018_Q3_M8.CSV"),
        sep="|",
        header=True,
        inferSchema=True,
        timestampFormat="yyyy-MM-dd",
    )
    .drop("BroadcastLogID", "SequenceNO")
    .withColumn(
        "duration_seconds",
        (
            F.col("Duration").substr(1, 2).cast("int") * 60 * 60
            + F.col("Duration").substr(4, 2).cast("int") * 60
            + F.col("Duration").substr(7, 2).cast("int")
        ),
    )
)

log_identifier = spark.read.csv(
    os.path.join(DIRECTORY, "ReferenceTables/LogIdentifier.csv"),
    sep="|",
    header=True,
    inferSchema=True,
)

cd_category = spark.read.csv(
    os.path.join(DIRECTORY, "ReferenceTables/CD_Category.csv"),
    sep="|",
    header=True,
    inferSchema=True,
).select(
    "CategoryID",
    "CategoryCD",
    F.col("EnglishDescription").alias("Category_Description"),
)

cd_program_class = spark.read.csv(
    os.path.join(DIRECTORY, "ReferenceTables/CD_ProgramClass.csv"),
    sep="|",
    header=True,
    inferSchema=True,
).select(
    "ProgramClassID",
    "ProgramClassCD",
    F.col("EnglishDescription").alias("ProgramClass_Description"),
)

# %%
logs_and_channels = logs.join(log_identifier, on="LogServiceID", how="inner")

# %%
full_log = logs_and_channels.join(cd_category, "CategoryID", how="left").join(
    cd_program_class, "ProgramClassID", how="left"
)

# %%
full_log.printSchema()
# Out:
# root
#  |-- ProgramClassID: integer (nullable = true)
#  |-- CategoryID: integer (nullable = true)
#  |-- LogServiceID: integer (nullable = true)
#  |-- LogDate: date (nullable = true)
#  |-- AudienceTargetAgeID: integer (nullable = true)
#  |-- AudienceTargetEthnicID: integer (nullable = true)
#  |-- ClosedCaptionID: integer (nullable = true)
#  |-- CountryOfOriginID: integer (nullable = true)
#  |-- DubDramaCreditID: integer (nullable = true)
#  |-- EthnicProgramID: integer (nullable = true)
#  |-- ProductionSourceID: integer (nullable = true)
#  |-- FilmClassificationID: integer (nullable = true)
#  |-- ExhibitionID: integer (nullable = true)
#  |-- Duration: string (nullable = true)
#  |-- EndTime: string (nullable = true)
#  |-- LogEntryDate: date (nullable = true)
#  |-- ProductionNO: string (nullable = true)
#  |-- ProgramTitle: string (nullable = true)
#  |-- StartTime: string (nullable = true)
#  |-- Subtitle: string (nullable = true)
#  |-- NetworkAffiliationID: integer (nullable = true)
#  |-- SpecialAttentionID: integer (nullable = true)
#  |-- BroadcastOriginPointID: integer (nullable = true)
#  |-- CompositionID: integer (nullable = true)
#  |-- Producer1: string (nullable = true)
#  |-- Producer2: string (nullable = true)
#  |-- Language1: integer (nullable = true)
#  |-- Language2: integer (nullable = true)
#  |-- duration_seconds: integer (nullable = true)
#  |-- LogIdentifierID: string (nullable = true)
#  |-- PrimaryFG: integer (nullable = true)
#  |-- CategoryCD: string (nullable = true)
#  |-- Category_Description: string (nullable = true)
#  |-- ProgramClassCD: string (nullable = true)
#  |-- ProgramClass_Description: string (nullable = true)

# %%
# Calculate final result and show result
answer = (full_log.groupby("LogIdentifierID")
    .agg(
        F.sum(
            F.when(
                F.trim(F.col("ProgramClassCD")).isin(["COM", "PRC", "PGI", "PRO", "LOC", "SPO", "MER", "SOL"]),
                F.col("duration_seconds")
                ).otherwise(0)).alias("duration_commercial"),
        F.sum("duration_seconds").alias("duration_total")
    )
    .withColumn("commercial_ratio", F.col("duration_commercial") / F.col("duration_total"))
    .orderBy("commercial_ratio", ascending=False)
    .withColumn("duration_commercial", F.format_number("duration_commercial", 0))
    .withColumn("duration_total", F.format_number("duration_total", 0))
    .withColumn("commercial_ratio", F.format_number("commercial_ratio", 2))
)

# %%
answer.show(10, False)
# Out:
# [Stage 11:===========================================>              (6 + 2) / 8]
# +---------------+-------------------+--------------+----------------+
# |LogIdentifierID|duration_commercial|duration_total|commercial_ratio|
# +---------------+-------------------+--------------+----------------+
# |CIMT           |19,935             |19,935        |1.00            |
# |TELENO         |545,255            |545,255       |1.00            |
# |MSET           |101,670            |101,670       |1.00            |
# |TANG           |271,468            |271,468       |1.00            |
# |TLNSP          |234,455            |234,455       |1.00            |
# |TRN            |403                |403           |1.00            |
# |HPITV          |403                |403           |1.00            |
# |INVST          |623,057            |633,659       |0.98            |
# |ZT�L�          |669,624            |682,023       |0.98            |
# |CANALZ         |669,624            |682,023       |0.98            |
# +---------------+-------------------+--------------+----------------+
# only showing top 10 rows

# %%
call_signs = spark.read.csv(
    "data/broadcast_logs/Call_Signs.csv", header=True
).drop("UndertakingNo")

# %%
call_signs.printSchema()
# Out:
# root
#  |-- LogIdentifierID: string (nullable = true)
#  |-- Undertaking_Name: string (nullable = true)

# %%
new_answer = answer.join(call_signs, on="LogIdentifierID")

# %%
new_answer.show(10, False)
# Out:
# [Stage 19:==================================================>       (7 + 1) / 8]
# +---------------+-------------------+--------------+----------------+--------------------------------------------------------+
# |LogIdentifierID|duration_commercial|duration_total|commercial_ratio|Undertaking_Name                                        |
# +---------------+-------------------+--------------+----------------+--------------------------------------------------------+
# |BRAVO          |701,000            |3,383,060     |0.21            |Bravo!                                                  |
# |CI             |720,130            |3,401,530     |0.21            |Crime + Investigation (formerly Mystery)                |
# |BOOK           |607,620            |3,292,170     |0.18            |Book Television (formerly Book Television - The Channel)|
# |BITE           |718,540            |3,411,100     |0.21            |Makeful TV (formerly BITE Television )                  |
# |CBKT           |539,627            |3,221,057     |0.17            |Canadian Broadcasting Corporation, regina (CBKT-DT)     |
# |CBHT           |532,878            |3,212,658     |0.17            |Canadian Broadcasting Corporation, halifax (CBHT-DT)    |
# |CBAFT          |406,067            |3,087,707     |0.13            |Société Radio-Canada, moncton (CBAFT-DT)                |
# |MAKE           |718,540            |3,411,100     |0.21            |Makeful TV (formerly BITE Television )                  |
# |13ST           |720,130            |3,401,530     |0.21            |Crime + Investigation (formerly Mystery)                |
# |BBCCND         |668,994            |3,350,299     |0.20            |BBC Canada                                              |
# +---------------+-------------------+--------------+----------------+--------------------------------------------------------+
# only showing top 10 rows
